# %% [markdown]
# <a href="https://colab.research.google.com/github/yleessam/tf/blob/main/transfer/pre_trained_model_%EC%82%AC%EC%9A%A9%ED%95%98%EA%B8%B0_%EB%B0%B0%ED%8F%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 필요 라이브러리 import

# %%
import cv2 as cv
import numpy as np
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from google.colab.patches import cv2_imshow

# %% [markdown]
# # ResNet50 모델 로드

# %% [markdown]
# - ImageNet 데이터셋에 대해 사전 훈련된 ResNet-50 모델을 로드
# 표준적인 224x224 픽셀 크기의 컬러 이미지를 입력으로 받고, ImageNet의 1000가지 클래스 중 하나로 이미지를 분류할 수 있는 완전 훈련된 모델 로드

# %%
#ResNet50 함수를 사용하여, ImageNet 데이터셋으로 사전 학습된 가중치를 가진 ResNet50 모델을 로드
model =
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 1s 0us/step

# %% [markdown]
# # 이미지 읽어오기

# %%
img =

# %% [markdown]
# # 이미지 전처리

# %%
# OpenCV를 사용하여 이미지를 ResNet50 모델이 요구하는 입력 크기인 224x224로 리사이즈
# 리사이즈된 이미지를 모델의 입력 형태에 맞게 차원을 변경합니다.
# 여기서 (1, 224, 224, 3)은 배치 크기 1, 높이 224, 너비 224, 채널 3(RGB)을 의미
x =
x =

# %% [markdown]
# # 예측 수행

# %%
#예측 수행
preds =

# 예측 결과를 해석하여 상위 5개의 예측 결과를 가져옵니다.
# 각 결과는 클래스 ID, 레이블 이름, 예측 확률로 구성
top5 =
print('예측 결과:', top5)

# 예측 결과를 이미지에 표시


# 이미지를 출력
# Out:
# 1/1 [==============================] - 0s 177ms/step
# 예측 결과: [('n02325366', 'wood_rabbit', 0.7427537), ('n02326432', 'hare', 0.24023704), ('n02328150', 'Angora', 0.008815734), ('n01877812', 'wallaby', 0.002689247), ('n02356798', 'fox_squirrel', 0.0012279289)]
# <PIL.Image.Image image mode=RGB size=484x599>
